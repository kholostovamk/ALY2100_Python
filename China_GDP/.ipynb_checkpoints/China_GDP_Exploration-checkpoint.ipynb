# %%
import json
import pandas as pd
from urllib.request import urlopen
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
url = "https://api.worldbank.org/v2/countries/CHN/indicators/NY.GDP.MKTP.CD?per_page=5000&format=json"
response = urlopen(url)
data_json = json.loads(response.read())
if isinstance(data_json, list) and len(data_json) > 1:
    # Normalize the data part (usually the second element in the list)
    df = pd.json_normalize(data_json[1])
else:
    df = pd.DataFrame()  # Fallback to an empty DataFrame if the structure is not as expected

df.head()
# Out:
#   countryiso3code  date         value unit obs_status  decimal  \
# 0             CHN  2022  1.796317e+13                        0
# 1             CHN  2021  1.782046e+13                        0
# 2             CHN  2020  1.468774e+13                        0
# 3             CHN  2019  1.427997e+13                        0
# 4             CHN  2018  1.389491e+13                        0
#
#      indicator.id    indicator.value country.id country.value
# 0  NY.GDP.MKTP.CD  GDP (current US$)         CN         China
# 1  NY.GDP.MKTP.CD  GDP (current US$)         CN         China
# 2  NY.GDP.MKTP.CD  GDP (current US$)         CN         China
# 3  NY.GDP.MKTP.CD  GDP (current US$)         CN         China
# 4  NY.GDP.MKTP.CD  GDP (current US$)         CN         China

# %%
#Transformed number into trillion for easier visualization
df['value_billions'] = df['value'] / 1e9
df.head()
# Out:
#   countryiso3code  date         value unit obs_status  decimal  \
# 0             CHN  2022  1.796317e+13                        0
# 1             CHN  2021  1.782046e+13                        0
# 2             CHN  2020  1.468774e+13                        0
# 3             CHN  2019  1.427997e+13                        0
# 4             CHN  2018  1.389491e+13                        0
#
#      indicator.id    indicator.value country.id country.value  value_billions
# 0  NY.GDP.MKTP.CD  GDP (current US$)         CN         China    17963.170521
# 1  NY.GDP.MKTP.CD  GDP (current US$)         CN         China    17820.459342
# 2  NY.GDP.MKTP.CD  GDP (current US$)         CN         China    14687.743557
# 3  NY.GDP.MKTP.CD  GDP (current US$)         CN         China    14279.968486
# 4  NY.GDP.MKTP.CD  GDP (current US$)         CN         China    13894.907485

# %%
df.describe(include='all')
# Out:
#        countryiso3code  date         value unit obs_status  decimal  \
# count               63    63  6.300000e+01   63         63     63.0
# unique               1    63           NaN    1          1      NaN
# top                CHN  2022           NaN                      NaN
# freq                63     1           NaN   63         63      NaN
# mean               NaN   NaN  3.062319e+12  NaN        NaN      0.0
# std                NaN   NaN  4.953679e+12  NaN        NaN      0.0
# min                NaN   NaN  4.720919e+10  NaN        NaN      0.0
# 25%                NaN   NaN  1.517400e+11  NaN        NaN      0.0
# 50%                NaN   NaN  3.833733e+11  NaN        NaN      0.0
# 75%                NaN   NaN  3.151223e+12  NaN        NaN      0.0
# max                NaN   NaN  1.796317e+13  NaN        NaN      0.0
#
#           indicator.id    indicator.value country.id country.value  \
# count               63                 63         63            63
# unique               1                  1          1             1
# top     NY.GDP.MKTP.CD  GDP (current US$)         CN         China
# freq                63                 63         63            63
# mean               NaN                NaN        NaN           NaN
# std                NaN                NaN        NaN           NaN
# min                NaN                NaN        NaN           NaN
# 25%                NaN                NaN        NaN           NaN
# 50%                NaN                NaN        NaN           NaN
# 75%                NaN                NaN        NaN           NaN
# max                NaN                NaN        NaN           NaN
#
#         value_billions
# count        63.000000
# unique             NaN
# top                NaN
# freq               NaN
# mean       3062.319399
# std        4953.678954
# min          47.209188
# 25%         151.739995
# 50%         383.373318
# 75%        3151.223056
# max       17963.170521

# %%
# Print the column names of the DataFrame
print(df.columns)
# Out:
# Index(['countryiso3code', 'date', 'value', 'unit', 'obs_status', 'decimal',
#        'indicator.id', 'indicator.value', 'country.id', 'country.value',
#        'value_billions'],
#       dtype='object')

# %%
descriptive_stats = df['value'].describe()
print(descriptive_stats)
# Out:
# count    6.300000e+01
# mean     3.062319e+12
# std      4.953679e+12
# min      4.720919e+10
# 25%      1.517400e+11
# 50%      3.833733e+11
# 75%      3.151223e+12
# max      1.796317e+13
# Name: value, dtype: float64

# %%
df.isnull().any().sum()
# Out:
# 0

# %%
# Convert 'date' to a datetime object and then extract the year as an integer
df['date'] = pd.to_datetime(df['date'], errors='coerce').dt.year


# Define the time periods (for example, before and after the year 2000)
split_year = 2000
before_2000 = df[df['date'] < split_year]['value'].dropna()
after_2000 = df[df['date'] >= split_year]['value'].dropna()

# Check if the subsets are populated
print("Number of entries before 2000:", before_2000.size)
print("Number of entries after 2000:", after_2000.size)

# Perform the independent samples t-test, if both subsets are non-empty
if not before_2000.empty and not after_2000.empty:
    t_test_result = stats.ttest_ind(before_2000, after_2000)
    print("T-Test Result:", t_test_result)
else:
    print("One or both subsets are empty, t-test cannot be performed")
# Out:
# Number of entries before 2000: 40
# Number of entries after 2000: 23
# T-Test Result: Ttest_indResult(statistic=-8.706969262130112, pvalue=2.6986241889477673e-12)

# %% [markdown]
# In the analysis, an independent samples t-test was conducted to compare the mean GDP values of China between two distinct time periods: before and after the year 2000. This test helps determine whether there is a statistically significant difference in China's average GDP between these two eras. The t-test yielded a statistic of -8.706969262130116 and a p-value of approximately 2.70e-12. The negative test statistic indicates that the mean GDP in the period before 2000 was lower than the mean GDP after 2000. The extremely small p-value, much lower than the conventional alpha level of 0.05, suggests that this difference in means is statistically significant. In terms of hypothesis testing, the null hypothesis (that there is no difference in mean GDP between the two periods) is rejected, indicating a significant change in China's GDP around the year 2000. This result could reflect substantial economic shifts or policy changes around the turn of the millennium, warranting further investigation into the contextual factors influencing these economic trends.

# %% [markdown]
# The Shapiro-Wilk test is a statistical procedure used to assess whether a dataset is normally distributed. It compares the distribution of the data against the normal distribution by calculating a W statistic, which indicates how much the data deviates from normality. This test was chosen because it's particularly effective for small to moderate-sized datasets, offering high sensitivity to deviations from a normal distribution.

# %%
# Perform the Shapiro-Wilk test for normality
# Ensure that you have no NaN values in the 'value' column
shapiro_test = stats.shapiro(df['value'].dropna())

# The Shapiro-Wilk test returns a tuple of the test statistic and the p-value
shapiro_stat, shapiro_p_value = shapiro_test

print(f"Shapiro-Wilk Test Statistic: {shapiro_stat}, P-Value: {shapiro_p_value}")

# Interpretation of the test
if shapiro_p_value > 0.05:
    print("The data follows a normal distribution (fail to reject H0).")
else:
    print("The data does not follow a normal distribution (reject H0).")
# Out:
# Shapiro-Wilk Test Statistic: 0.6551258563995361, P-Value: 6.807249902651691e-11
# The data does not follow a normal distribution (reject H0).

# %% [markdown]
# To prove info above:

# %%
# Drop NaN values from the 'value' column for accurate representation
data = df['value'].dropna()

# Calculate mean and standard deviation of the data
mean = np.mean(data)
std = np.std(data)

# Plot the histogram of the data
plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, density=True, alpha=0.6, color='g')

# Plot the normal distribution with the same mean and standard deviation
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = stats.norm.pdf(x, mean, std)
plt.plot(x, p, 'k', linewidth=2)

title = "Fit results: mean = %.2f,  std = %.2f" % (mean, std)
plt.title(title)
plt.xlabel('GDP Value')
plt.ylabel('Density')

# Show the plot
plt.show()

# %%
df = df.sort_values(by='date')

# Create a plot of 'value' by 'date'
plt.figure(figsize=(18, 6))  # Set the figure size
plt.plot(df['date'], df['value_billions'], marker='o')  # Plot 'value' against 'date'

# Add titles and labels
plt.title('GDP Value by Year')
plt.xlabel('Year')
plt.ylabel('GDP Value in Billions')

plt.xticks(rotation=45)  # Rotate the labels by 45 degrees

# Show the plot
plt.show()

# %%
gdp_date_corr = df['value'].corr(df['date'])

print("Correltion of year with value of GDP: ", gdp_date_corr )
# Out:
# Correltion of year with value of GDP:  0.7849067828389961

# %%
df['value_billions'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Since initial dataset does not have a lot of information except value of GDP I will merge it with data from other sources.

# %%
#adding new dataset to extract inflation as new feature

filename = 'Countries_inflation1960-2021.csv'

df_inflation = pd.read_csv(filename)

#filter data set only for China inflation info

china_inflation_df = df_inflation[df_inflation['Country Name'] == 'China']

china_inflation_df.head()
# Out:
#    Country Name Country Code                         Indicator Name  \
# 40        China          CHN  Inflation, consumer prices (annual %)
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...      2012  \
# 40  FP.CPI.TOTL.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ...  2.619524
#
#        2013      2014      2015      2016      2017     2018      2019  \
# 40  2.62105  1.921642  1.437024  2.000002  1.593136  2.07479  2.899234
#
#         2020      2021
# 40  2.419422  0.981015
#
# [1 rows x 66 columns]

# %% [markdown]
# Merging newly made column with existing df

# %%
#rename 'date' column in df to year for consistency
df = df.rename(columns = {'date': 'Year' })

#making sure year is in format int
df['Year'] = df['Year'].astype(int)


china_inflation_df = pd.DataFrame(china_inflation_df)
china_inflation_df.head()
# Out:
#    Country Name Country Code                         Indicator Name  \
# 40        China          CHN  Inflation, consumer prices (annual %)
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...      2012  \
# 40  FP.CPI.TOTL.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ...  2.619524
#
#        2013      2014      2015      2016      2017     2018      2019  \
# 40  2.62105  1.921642  1.437024  2.000002  1.593136  2.07479  2.899234
#
#         2020      2021
# 40  2.419422  0.981015
#
# [1 rows x 66 columns]

# %%
year_columns = china_inflation_df.columns[4:]

china_long_format = pd.melt(china_inflation_df, 
                            value_vars=year_columns, 
                            var_name='Year', 
                            value_name='inflation_rate')

china_long_format['Year'] = china_long_format['Year'].astype(int)

merged_df = pd.merge(df, china_long_format, on='Year')

# %% [markdown]
# Adding another dataset with information about export, import, household consumption, capital investment & government spending.

# %%
filename = 'china_economy_data.csv'

df_china_economy = pd.read_csv(filename)

df_china_economy.head()
# Out:
#   Country Code ContinentCode  Year  Capital investment billion USD  \
# 0   China  CHN            AS  1960                           23.64
# 1   China  CHN            AS  1961                           11.42
# 2   China  CHN            AS  1962                            7.43
# 3   China  CHN            AS  1963                           11.03
# 4   China  CHN            AS  1964                           14.54
#
#    Household consumption billion USD  \
# 0                              30.13
# 1                              33.17
# 2                              34.07
# 3                              34.29
# 4                              36.14
#
#    Exports of goods and services billion USD  \
# 0                                       2.57
# 1                                       1.94
# 2                                       1.91
# 3                                       2.03
# 4                                       2.25
#
#    Imports of goods and services billion USD  Government spending billion USD
# 0                                       2.64                             7.43
# 1                                       1.75                             7.16
# 2                                       1.37                             5.99
# 3                                       1.45                             6.86
# 4                                       1.71                             7.57

# %%
df_china_economy['Year'] = df_china_economy['Year'].astype(int)
merged_df  = pd.merge(merged_df, df_china_economy, on='Year')

merged_df.head()
# Out:
#   countryiso3code  Year         value unit obs_status  decimal  \
# 0             CHN  1960  5.971625e+10                        0
# 1             CHN  1961  5.005669e+10                        0
# 2             CHN  1962  4.720919e+10                        0
# 3             CHN  1963  5.070662e+10                        0
# 4             CHN  1964  5.970813e+10                        0
#
#      indicator.id    indicator.value country.id country.value  value_billions  \
# 0  NY.GDP.MKTP.CD  GDP (current US$)         CN         China       59.716252
# 1  NY.GDP.MKTP.CD  GDP (current US$)         CN         China       50.056688
# 2  NY.GDP.MKTP.CD  GDP (current US$)         CN         China       47.209188
# 3  NY.GDP.MKTP.CD  GDP (current US$)         CN         China       50.706617
# 4  NY.GDP.MKTP.CD  GDP (current US$)         CN         China       59.708128
#
#    inflation_rate Country Code ContinentCode  Capital investment billion USD  \
# 0             NaN   China  CHN            AS                           23.64
# 1             NaN   China  CHN            AS                           11.42
# 2             NaN   China  CHN            AS                            7.43
# 3             NaN   China  CHN            AS                           11.03
# 4             NaN   China  CHN            AS                           14.54
#
#    Household consumption billion USD  \
# 0                              30.13
# 1                              33.17
# 2                              34.07
# 3                              34.29
# 4                              36.14
#
#    Exports of goods and services billion USD  \
# 0                                       2.57
# 1                                       1.94
# 2                                       1.91
# 3                                       2.03
# 4                                       2.25
#
#    Imports of goods and services billion USD  Government spending billion USD
# 0                                       2.64                             7.43
# 1                                       1.75                             7.16
# 2                                       1.37                             5.99
# 3                                       1.45                             6.86
# 4                                       1.71                             7.57

# %%
#dropping useless columns and value column, since all other info is in billions
columns_to_drop = ['value','countryiso3code', 'unit', 'obs_status', 'decimal', 'indicator.id', 'indicator.value', 'country.id', 'country.value', 'Country', 'Code', 'ContinentCode']
merged_df = merged_df.drop(columns=columns_to_drop, axis=1)

merged_df.head()
# Out:
#    Year  value_billions  inflation_rate  Capital investment billion USD  \
# 0  1960       59.716252             NaN                           23.64
# 1  1961       50.056688             NaN                           11.42
# 2  1962       47.209188             NaN                            7.43
# 3  1963       50.706617             NaN                           11.03
# 4  1964       59.708128             NaN                           14.54
#
#    Household consumption billion USD  \
# 0                              30.13
# 1                              33.17
# 2                              34.07
# 3                              34.29
# 4                              36.14
#
#    Exports of goods and services billion USD  \
# 0                                       2.57
# 1                                       1.94
# 2                                       1.91
# 3                                       2.03
# 4                                       2.25
#
#    Imports of goods and services billion USD  Government spending billion USD
# 0                                       2.64                             7.43
# 1                                       1.75                             7.16
# 2                                       1.37                             5.99
# 3                                       1.45                             6.86
# 4                                       1.71                             7.57

# %%
print(merged_df.shape)

merged_df.corr()
# Out:
# (62, 8)
#                                                Year  value_billions  \
# Year                                       1.000000        0.778624
# value_billions                             0.778624        1.000000
# inflation_rate                            -0.529803       -0.360871
# Capital investment billion USD             0.774843        0.999243
# Household consumption billion USD          0.777444        0.998999
# Exports of goods and services billion USD  0.812612        0.983076
# Imports of goods and services billion USD  0.806580        0.987202
# Government spending billion USD            0.769053        0.999050
#
#                                            inflation_rate  \
# Year                                            -0.529803
# value_billions                                  -0.360871
# inflation_rate                                   1.000000
# Capital investment billion USD                  -0.354053
# Household consumption billion USD               -0.361818
# Exports of goods and services billion USD       -0.387571
# Imports of goods and services billion USD       -0.379157
# Government spending billion USD                 -0.357443
#
#                                            Capital investment billion USD  \
# Year                                                             0.774843
# value_billions                                                   0.999243
# inflation_rate                                                  -0.354053
# Capital investment billion USD                                   1.000000
# Household consumption billion USD                                0.996818
# Exports of goods and services billion USD                        0.985477
# Imports of goods and services billion USD                        0.990106
# Government spending billion USD                                  0.997654
#
#                                            Household consumption billion USD  \
# Year                                                                0.777444
# value_billions                                                      0.998999
# inflation_rate                                                     -0.361818
# Capital investment billion USD                                      0.996818
# Household consumption billion USD                                   1.000000
# Exports of goods and services billion USD                           0.975702
# Imports of goods and services billion USD                           0.980760
# Government spending billion USD                                     0.999356
#
#                                            Exports of goods and services billion USD  \
# Year                                                                        0.812612
# value_billions                                                              0.983076
# inflation_rate                                                             -0.387571
# Capital investment billion USD                                              0.985477
# Household consumption billion USD                                           0.975702
# Exports of goods and services billion USD                                   1.000000
# Imports of goods and services billion USD                                   0.998116
# Government spending billion USD                                             0.975952
#
#                                            Imports of goods and services billion USD  \
# Year                                                                        0.806580
# value_billions                                                              0.987202
# inflation_rate                                                             -0.379157
# Capital investment billion USD                                              0.990106
# Household consumption billion USD                                           0.980760
# Exports of goods and services billion USD                                   0.998116
# Imports of goods and services billion USD                                   1.000000
# Government spending billion USD                                             0.981295
#
#                                            Government spending billion USD
# Year                                                              0.769053
# value_billions                                                    0.999050
# inflation_rate                                                   -0.357443
# Capital investment billion USD                                    0.997654
# Household consumption billion USD                                 0.999356
# Exports of goods and services billion USD                         0.975952
# Imports of goods and services billion USD                         0.981295
# Government spending billion USD                                   1.000000

# %%
sns.heatmap(merged_df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Since many of these features are highly correlated with each other, using them all in a predictive model might lead to multicollinearity issues.We can try Principle Component Analysis to reduce dimensionality and retaining most of information.
# However before that we need to clean the data:
#  - Handle missing data
#  - Normalize data
#  - Check for any inconsistencies

# %%
merged_df.isnull().sum()
# Out:
# Year                                          0
# value_billions                                0
# inflation_rate                               27
# Capital investment billion USD                0
# Household consumption billion USD             0
# Exports of goods and services billion USD     0
# Imports of goods and services billion USD     0
# Government spending billion USD               0
# dtype: int64

# %% [markdown]
# The only columns with missing values is inflation rate. It is available only after year 1987.

# %% [markdown]
# Normalizing all dat to be on the same scale, except for Year column.

# %%
# Normalize data
years = merged_df['Year']
merged_df_without_year = merged_df.drop('Year', axis=1)

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Normalize the data
normalized_data = scaler.fit_transform(merged_df_without_year)

# Create a new DataFrame with the normalized data
normalized_df = pd.DataFrame(normalized_data, columns=merged_df_without_year.columns)

# Add the 'Year' column back to the normalized DataFrame
normalized_df['Year'] = years.values

# Rename normalized_df to merged_df
merged_df = normalized_df

# Now, merged_df contains all columns normalized, with 'Year' as a column
merged_df.head()
# Out:
#    value_billions  inflation_rate  Capital investment billion USD  \
# 0        0.000704             NaN                        0.002111
# 1        0.000160             NaN                        0.000520
# 2        0.000000             NaN                        0.000000
# 3        0.000197             NaN                        0.000469
# 4        0.000703             NaN                        0.000926
#
#    Household consumption billion USD  \
# 0                           0.000000
# 1                           0.000450
# 2                           0.000583
# 3                           0.000615
# 4                           0.000889
#
#    Exports of goods and services billion USD  \
# 0                                   0.000186
# 1                                   0.000008
# 2                                   0.000000
# 3                                   0.000034
# 4                                   0.000096
#
#    Imports of goods and services billion USD  Government spending billion USD  \
# 0                                   0.000411                         0.000512
# 1                                   0.000123                         0.000416
# 2                                   0.000000                         0.000000
# 3                                   0.000026                         0.000309
# 4                                   0.000110                         0.000562
#
#    Year
# 0  1960
# 1  1961
# 2  1962
# 3  1963
# 4  1964

# %%
# Create a histogram
plt.figure(figsize=(20,10))
plt.plot(merged_df['Year'], merged_df['inflation_rate'], marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('Inflation Rate (%)')
plt.title('Inflation Rate by Year')
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
merged_df['inflation_rate'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: inflation_rate, dtype: float64

# %% [markdown]
# For imputation of missing values we will use ARIMA (AutoRegressive Integrated Moving Average) model which is typically used for predicting future points in a time series based on past data. However, it can also be adapted for imputation, where the goal is to fill in missing past data points even if those points are in the past.  This approach ensures that the imputed values are not just random fill-ins but are informed by the inherent patterns and trends in data.

# %%
#making a times series of inflation for future imputation

years = merged_df['Year'].tolist()
inflation_data = merged_df.set_index('Year')['inflation_rate']

# Create a Series
inflation_data = pd.Series(inflation_data)

# Display the Series
print(inflation_data)
# Out:
# Year
# 1960         NaN
# 1961         NaN
# 1962         NaN
# 1963         NaN
# 1964         NaN
#           ...
# 2017    0.116710
# 2018    0.135482
# 2019    0.167614
# 2020    0.148914
# 2021    0.092854
# Name: inflation_rate, Length: 62, dtype: float64

# %%
inflation_data.index = pd.to_datetime(inflation_data.index, format='%Y') #need format of yyyy-mm-dd

#apparently ARIMA doesnt work when values are missing, so have to fill as the first step (weird)
inflation_filled = inflation_data.fillna(inflation_data.median())
#inflation_filled = inflation_data.fillna(inflation_data.mean())
#inflation_filled = inflation_data.fillna(0)


# Use auto_arima to find the best ARIMA model
auto_model = auto_arima(inflation_filled, seasonal=False, m=1, trace=True, error_action='ignore', suppress_warnings=True)
best_order = auto_model.order

# Fit the ARIMA model
arima_model = ARIMA(inflation_filled, order=best_order)
arima_fitted = arima_model.fit()

# Predict the missing values for the years 1960-1986
predicted_values = arima_fitted.predict(start=pd.to_datetime('1960'), end=pd.to_datetime('1986'))

# Replace the missing values in your original series
inflation_data.update(predicted_values)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-81.021, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=18.423, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-63.824, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-46.048, Time=0.01 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-79.282, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-77.249, Time=0.03 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=-78.954, Time=0.07 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=-79.013, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-77.931, Time=0.04 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=-80.417, Time=0.05 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=-75.748, Time=0.03 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=-77.976, Time=0.07 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-83.328, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-85.301, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=-85.965, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-80.348, Time=0.02 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=-85.549, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-87.293, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-68.396, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-85.303, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-29.844, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-78.783, Time=0.01 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 0.776 seconds
# /Users/admin/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# /Users/admin/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# /Users/admin/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)

# %%
inflation_data.head(27)
# Out:
# Year
# 1960-01-01    0.202375
# 1961-01-01    0.170563
# 1962-01-01    0.176019
# 1963-01-01    0.170899
# 1964-01-01    0.173618
# 1965-01-01    0.171182
# 1966-01-01    0.172781
# 1967-01-01    0.171400
# 1968-01-01    0.172388
# 1969-01-01    0.171559
# 1970-01-01    0.172178
# 1971-01-01    0.171669
# 1972-01-01    0.172058
# 1973-01-01    0.171742
# 1974-01-01    0.171987
# 1975-01-01    0.171790
# 1976-01-01    0.171944
# 1977-01-01    0.171820
# 1978-01-01    0.171918
# 1979-01-01    0.171840
# 1980-01-01    0.171901
# 1981-01-01    0.171853
# 1982-01-01    0.171891
# 1983-01-01    0.171861
# 1984-01-01    0.171885
# 1985-01-01    0.171865
# 1986-01-01    0.171881
# Name: inflation_rate, dtype: float64

# %%
#see the result of imputation
years = inflation_data.index  # Get the years for the x-axis
inflation_rates = inflation_data.values  # Get the inflation rates for the y-axis

plt.figure(figsize=(10, 6))
plt.plot(years, inflation_rates, marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('Inflation Rate (%)')
plt.title('Inflation Rate by Year')
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusion: I might as well just imputed it with mean or median.
