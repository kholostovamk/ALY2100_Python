# %% [markdown]
# # Assignment 1 - ALY2100 CRN SEC 02 Fall 2023 CPS
#
# ---
# Student: Margarita Kholostova
#
# Instructor: Vladimir Shapiro
#
# Date: September 10, 2023
#
# ---

# %% [markdown]
# ## Introduction
#
# In today's world, we often combine human communication with computer usage. This assignment explores this combination. It's aim is to discover how conversational interactions can be similar to giving instructions to a computer.
#
# We will plan to converse with a new student for the first task. We will use a visual aid (flow chart) and simplified instructions (pseudo-code). This plan illustrates how a conversation can branch off based on different responses. In the subsequent segment, we will utilize a tool named Jupyter to pose questions and display the answers. This exercise underscores the significance of framing the right questions in a digital setting or a face-to-face conversation. Through these tasks, we aim to draw parallels between human conversations and computer programming.

# %% [markdown]
# ## Analysis

# %% [markdown]
# ## Part 1:
#
# Draw a flow chart of how you would tackle asking a couple of questions, getting the answers, and creating a dialogue with a prospective student. Write in Pseudo-Code in English to emulate this dialogue.

# %% [markdown]
# **S1**: Hi! How can I help you?
#
# **S2**: Hi! I am considering enrolling in a tech course but not sure which one to choose.
#
# **S1**: I can help you with that. For starters, would you be interested in building websites or do you want to start with understanding how computers work?
#
# **S2**:
# - **A**: I'm curious about how computers work.
# - **B**: I'd like to learn how to build websites.
#
# ---
#
# *If choice A:*
#
# **S2**: Wonderful! Our "Operating Systems Concepts" course would be perfect for you. It will help you understand the fundamentals of how computers operate. Would you like more details about this course?
#
# **S1**:
# - **A**: Yes, please.
# - **B**: No, how do I enroll?
#
# ---
#
# *If choice B:*
#
# **S2**: Great choice! Our "Web Development Basics" course will introduce you to the world of website creation. You'll learn about designing and coding websites. Do you want more information about what's covered in the course?
#
# **S1**:
# - **A**: Yes, please.
# - **B**: No, please help me enroll.

# %% [markdown]
# **FLOWCHART:**

# %% [markdown]
# ![MODULE%201%20ALY%20ASSIGNMENT%20%281%29.svg](attachment:MODULE%201%20ALY%20ASSIGNMENT%20%281%29.svg)

# %% [markdown]
# Figure 1. Flowchart illustrating student dialogue sequence.

# %% [markdown]
# ## PART 2:

# %% [markdown]
# Using Jupyter, create one variable by asking the user ( for example, your colleague) why she/he enrolled in this program and a second one by asking what they want to learn from this course; print both. You can come up with any two questions you want with any audience you prefer, as long as they shape a dialogue sequence.

# %%
# First question
motivation = input("Why did you decide to join this programming course? ")
# Out:
# Why did you decide to join this programming course? I need Python to become successful in my career.

# %%
# Second question
goal = input("What specific skills or topics are you hoping to master in this course? ")
# Out:
# What specific skills or topics are you hoping to master in this course? I want to be proficient in Python, and master my skills in Machine Learning and Deep Learning

# %%
# Both answers
print("\nYour motivation for joining the course:\n", motivation)
print("Skills or topics you want to master:\n", goal)
# Out:
# Your motivation for joining the course:
#  I need Python to become successful in my career.
# Skills or topics you want to master:
#  I want to be proficient in Python, and master my skills in Machine Learning and Deep Learning

# %% [markdown]
# # Conclusions
#
#
# - Translated the visual dialogue pathway into pseudo-code, showcasing the logical structure of the conversation and ensuring a systematic approach to handling diverse student responses.
# - Developed a flowchart to effectively map out the process of initiating and navigating a conversation with a prospective student, highlighting the decision-making paths based on various responses.
# - Successfully demonstrated the ability to craft a tailored dialogue in Python within the Jupyter environment, capturing user motivations for enrolling in a program and their specific learning objectives, emphasizing the importance of direct interaction and feedback.

# %% [markdown]
# # References
#
# 1. Kholostova, M. (2023). Flowchart illustrating student dialogue sequence [Flowchart]. Lucidchart.
